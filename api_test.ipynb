# %%
import requests
import pandas as pd

# %%
url = 'http://127.0.0.1:5000/regression/predict'

payload = {
    'Name' : 'taskdelay',
    'Data' : {
        'Cost' : 1000,
        'Priority' : 1,
        'Progress' : 50,
        'Duration' : 10,
        'Worker' : 3,
        'TaskLength' : 10,
        'IsBadWeather' : 1,
        'WeatherAssessment' : 20,
        'StartDelay' : 2,
        'DayCount' : 10,
        'Is_Delayed' : 0
    }
}

response = requests.post(url, json=payload)

print(f'Status Code: {response.status_code}')
print(f'Response JSON: {response.json()}')
# Out:
# Status Code: 200
# Response JSON: {'model_name': 'taskdelay', 'prediction': [3.059045605893361]}

# %%
import pandas as pd

# %%
data = pd.read_csv('data\Treatment Perfomance 1990-2023.csv')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13896\1350825829.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data\Treatment Perfomance 1990-2023.csv')

# %%
data.save('d:\\Work\\Angusta System\\endpoint-automl\\api_engine_regression\\api_engine_regression/static/files\\dataset_haoey.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13896\76526858.py in ?()
# ----> 1 data.save('d:\\Work\\Angusta System\\endpoint-automl\\api_engine_regression\\api_engine_regression/static/files\\dataset_haoey.csv')
#
# c:\Users\Acer\anaconda3\envs\engine\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'save'
